# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Apr 17 01:19:29 2020

@author: hisham
"""
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Apr 16 21:31:02 2020

@author: hisham
"""

# import math
import chardet
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import psycopg2


import requests
import json
from flask import jsonify
from csv import writer


url = 'https://corona-api.com/countries/'
url_iso2 = 'https://restcountries.eu/rest/v2/'

querystring = {"country":"Bangladesh"}

headers = {
    'x-rapidapi-host': "coronavirus-monitor.p.rapidapi.com",
    'x-rapidapi-key': "b23312c441msh260b60b1bd6e484p1f47f7jsnd56b11696dd9"
    }

response_iso2 = requests.get(url_iso2)


lst_iso2 = json.loads(response_iso2.text)

# for i in lst_iso2:
#     print(i['alpha2Code'])

with open('country_timeline1.csv', 'w') as csv_file:
    csv_writer = writer(csv_file)
    headers = ['Country_name', 'Country_code_iso2', 'Country_code_iso3', 'Date', 'New_confirmed', 'New_deaths']
    csv_writer.writerow(headers)
    for i in lst_iso2:
        # print(i['alpha2Code'])
        country_name = i['name']
        country_code2 = i['alpha2Code']
        country_code3 = i['alpha3Code']
        lnk = url + country_code2
        print(lnk)
        response = requests.get(lnk)
    

        lst = json.loads(response.text)
        print(country_code2)
        if 'data' in lst:
            if(len(lst['data']['timeline']) > 0):
                for j in lst['data']['timeline']:
                    date = j['date']
                    new_confirmed = j['new_confirmed']
                    new_deaths = j['new_deaths']
                    entry = [country_name, country_code2, country_code3, date, new_confirmed, new_deaths]
                    csv_writer.writerow(entry)


                    
with open('country_timeline1.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large

print(result)

dataset = pd.read_csv('country_timeline1.csv', keep_default_na=False,  encoding=result['encoding'])
X = dataset.iloc[:, :].values
Z = dataset.iloc[0:540, :].values


def buildZ(i, date):
    for row in X:
        if row[3] == date:
            Z[i] = row
            i = i + 1
    # print(i)            
i = 0
buildZ(i, '2020-04-17')
buildZ(i+180, '2020-04-16')
buildZ(i+2*180, '2020-04-15')


for i in range(180):
    if (Z[i][0] != Z[i+180][0]) or (Z[i][0] != Z[i+360][0]):
        print(Z[i][0])
        
new = Z
new = np.append(new, np.zeros((540,8)), axis = 1)

for i in range(180):
    new[i][6] = new[i+180][4]
    new[i][7] = new[i+180][5]
    new[i][8] = new[i+2*180][4]
    new[i][9] = new[i+2*180][5]

top = new

def inputTop(d, a, b, c):
    for i in range(len(top)):
        avg = (top[i][a] + top[i][b] + top[i][c])/3
        
        if top[i][a] > top[i][b] and top[i][b] > top[i][c]:
            top[i][d] = top[i][a] + (top[i][a] - top[i][c])/4 - (top[i][b] - top[i][c])/4
            if top[i][d] < 0:
                top[i][d] = 0            
        elif top[i][a] < top[i][b] and top[i][b] < top[i][c]:   
            top[i][d] = avg - (top[i][c] - top[i][a])/4 + (top[i][c] - top[i][b])/3 
            if top[i][d] < 0:
                top[i][d] = 0
        else:
            if top[i][a] > top[i][b] and top[i][b] < top[i][c]:
                top[i][d] = avg + (top[i][a] - top[i][b])/5
            elif top[i][a] < top[i][b] and top[i][b] > top[i][c]:              
                top[i][d] = avg + (top[i][b] - top[i][c])/5
            else:
                top[i][d] = avg
                
inputTop(10, 4, 6, 8)
inputTop(11, 5, 7, 9)
inputTop(12, 10, 4, 6)
inputTop(13, 11, 5, 7)
top[:, [10,11,12,13]] = top[:, [10,11,12,13]].astype(int)

dbase = top[0:180, [0, 2, 3, 4, 5, 10, 11, 12, 13]]

# date manipulation
from datetime import datetime as dt, timedelta
one_day = timedelta(days=1)
yesterday_str = dbase[0][2]
yesterday = dt.strptime(yesterday_str, '%Y-%m-%d').date()
today = yesterday + one_day
today_str = today.strftime("%Y-%m-%d")
i = np.full((180,1), today_str)
dbase = np.hstack((dbase[:,:5], i, dbase[:,5:]))
tomorrow = today + one_day
tomorrow_str = tomorrow.strftime("%Y-%m-%d")
i = np.full((180,1), tomorrow_str)
dbase = np.hstack((dbase[:,:8], i, dbase[:,8:]))


"""
dbase[:,0] = country
dbase[:,1] = code
dbase[:,2] = date_yesterday
dbase[:,3] = affected_yesterday
dbase[:,4] = death_yesterday
dbase[:,5] = date_today
dbase[:,6] = affected_today
dbase[:,7] = death_today
dbase[:,8] = date_tomorrow
dbase[:,9] = affected_tomorrow
dbase[:,10] = death_tomorrow
"""
# Out:
# https://corona-api.com/countries/AF
# AF
# https://corona-api.com/countries/AX
# AX
# https://corona-api.com/countries/AL
# AL
# https://corona-api.com/countries/DZ
# DZ
# https://corona-api.com/countries/AS
# AS
# https://corona-api.com/countries/AD
# AD
# https://corona-api.com/countries/AO
# AO
# https://corona-api.com/countries/AI
# AI
# https://corona-api.com/countries/AQ
# AQ
# https://corona-api.com/countries/AG
# AG
# https://corona-api.com/countries/AR
# AR
# https://corona-api.com/countries/AM
# AM
# https://corona-api.com/countries/AW
# AW
# https://corona-api.com/countries/AU
# AU
# https://corona-api.com/countries/AT
# AT
# https://corona-api.com/countries/AZ
# AZ
# https://corona-api.com/countries/BS
# BS
# https://corona-api.com/countries/BH
# BH
# https://corona-api.com/countries/BD
# BD
# https://corona-api.com/countries/BB
# BB
# https://corona-api.com/countries/BY
# BY
# https://corona-api.com/countries/BE
# BE
# https://corona-api.com/countries/BZ
# BZ
# https://corona-api.com/countries/BJ
# BJ
# https://corona-api.com/countries/BM
# BM
# https://corona-api.com/countries/BT
# BT
# https://corona-api.com/countries/BO
# BO
# https://corona-api.com/countries/BQ
# BQ
# https://corona-api.com/countries/BA
# BA
# https://corona-api.com/countries/BW
# BW
# https://corona-api.com/countries/BV
# BV
# https://corona-api.com/countries/BR
# BR
# https://corona-api.com/countries/IO
# IO
# https://corona-api.com/countries/UM
# UM
# https://corona-api.com/countries/VG
# VG
# https://corona-api.com/countries/VI
# VI
# https://corona-api.com/countries/BN
# BN
# https://corona-api.com/countries/BG
# BG
# https://corona-api.com/countries/BF
# BF
# https://corona-api.com/countries/BI
# BI
# https://corona-api.com/countries/KH
# KH
# https://corona-api.com/countries/CM
# CM
# https://corona-api.com/countries/CA
# CA
# https://corona-api.com/countries/CV
# CV
# https://corona-api.com/countries/KY
# KY
# https://corona-api.com/countries/CF
# CF
# https://corona-api.com/countries/TD
# TD
# https://corona-api.com/countries/CL
# CL
# https://corona-api.com/countries/CN
# CN
# https://corona-api.com/countries/CX
# CX
# https://corona-api.com/countries/CC
# CC
# https://corona-api.com/countries/CO
# CO
# https://corona-api.com/countries/KM
# KM
# https://corona-api.com/countries/CG
# CG
# https://corona-api.com/countries/CD
# CD
# https://corona-api.com/countries/CK
# CK
# https://corona-api.com/countries/CR
# CR
# https://corona-api.com/countries/HR
# HR
# https://corona-api.com/countries/CU
# CU
# https://corona-api.com/countries/CW
# CW
# https://corona-api.com/countries/CY
# CY
# https://corona-api.com/countries/CZ
# CZ
# https://corona-api.com/countries/DK
# DK
# https://corona-api.com/countries/DJ
# DJ
# https://corona-api.com/countries/DM
# DM
# https://corona-api.com/countries/DO
# DO
# https://corona-api.com/countries/EC
# EC
# https://corona-api.com/countries/EG
# EG
# https://corona-api.com/countries/SV
# SV
# https://corona-api.com/countries/GQ
# GQ
# https://corona-api.com/countries/ER
# ER
# https://corona-api.com/countries/EE
# EE
# https://corona-api.com/countries/ET
# ET
# https://corona-api.com/countries/FK
# FK
# https://corona-api.com/countries/FO
# FO
# https://corona-api.com/countries/FJ
# FJ
# https://corona-api.com/countries/FI
# FI
# https://corona-api.com/countries/FR
# FR
# https://corona-api.com/countries/GF
# GF
# https://corona-api.com/countries/PF
# PF
# https://corona-api.com/countries/TF
# TF
# https://corona-api.com/countries/GA
# GA
# https://corona-api.com/countries/GM
# GM
# https://corona-api.com/countries/GE
# GE
# https://corona-api.com/countries/DE
# DE
# https://corona-api.com/countries/GH
# GH
# https://corona-api.com/countries/GI
# GI
# https://corona-api.com/countries/GR
# GR
# https://corona-api.com/countries/GL
# GL
# https://corona-api.com/countries/GD
# GD
# https://corona-api.com/countries/GP
# GP
# https://corona-api.com/countries/GU
# GU
# https://corona-api.com/countries/GT
# GT
# https://corona-api.com/countries/GG
# GG
# https://corona-api.com/countries/GN
# GN
# https://corona-api.com/countries/GW
# GW
# https://corona-api.com/countries/GY
# GY
# https://corona-api.com/countries/HT
# HT
# https://corona-api.com/countries/HM
# HM
# https://corona-api.com/countries/VA
# VA
# https://corona-api.com/countries/HN
# HN
# https://corona-api.com/countries/HK
# HK
# https://corona-api.com/countries/HU
# HU
# https://corona-api.com/countries/IS
# IS
# https://corona-api.com/countries/IN
# IN
# https://corona-api.com/countries/ID
# ID
# https://corona-api.com/countries/CI
# CI
# https://corona-api.com/countries/IR
# IR
# https://corona-api.com/countries/IQ
# IQ
# https://corona-api.com/countries/IE
# IE
# https://corona-api.com/countries/IM
# IM
# https://corona-api.com/countries/IL
# IL
# https://corona-api.com/countries/IT
# IT
# https://corona-api.com/countries/JM
# JM
# https://corona-api.com/countries/JP
# JP
# https://corona-api.com/countries/JE
# JE
# https://corona-api.com/countries/JO
# JO
# https://corona-api.com/countries/KZ
# KZ
# https://corona-api.com/countries/KE
# KE
# https://corona-api.com/countries/KI
# KI
# https://corona-api.com/countries/KW
# KW
# https://corona-api.com/countries/KG
# KG
# https://corona-api.com/countries/LA
# LA
# https://corona-api.com/countries/LV
# LV
# https://corona-api.com/countries/LB
# LB
# https://corona-api.com/countries/LS
# LS
# https://corona-api.com/countries/LR
# LR
# https://corona-api.com/countries/LY
# LY
# https://corona-api.com/countries/LI
# LI
# https://corona-api.com/countries/LT
# LT
# https://corona-api.com/countries/LU
# LU
# https://corona-api.com/countries/MO
# MO
# https://corona-api.com/countries/MK
# MK
# https://corona-api.com/countries/MG
# MG
# https://corona-api.com/countries/MW
# MW
# https://corona-api.com/countries/MY
# MY
# https://corona-api.com/countries/MV
# MV
# https://corona-api.com/countries/ML
# ML
# https://corona-api.com/countries/MT
# MT
# https://corona-api.com/countries/MH
# MH
# https://corona-api.com/countries/MQ
# MQ
# https://corona-api.com/countries/MR
# MR
# https://corona-api.com/countries/MU
# MU
# https://corona-api.com/countries/YT
# YT
# https://corona-api.com/countries/MX
# MX
# https://corona-api.com/countries/FM
# FM
# https://corona-api.com/countries/MD
# MD
# https://corona-api.com/countries/MC
# MC
# https://corona-api.com/countries/MN
# MN
# https://corona-api.com/countries/ME
# ME
# https://corona-api.com/countries/MS
# MS
# https://corona-api.com/countries/MA
# MA
# https://corona-api.com/countries/MZ
# MZ
# https://corona-api.com/countries/MM
# MM
# https://corona-api.com/countries/NA
# NA
# https://corona-api.com/countries/NR
# NR
# https://corona-api.com/countries/NP
# NP
# https://corona-api.com/countries/NL
# NL
# https://corona-api.com/countries/NC
# NC
# https://corona-api.com/countries/NZ
# NZ
# https://corona-api.com/countries/NI
# NI
# https://corona-api.com/countries/NE
# NE
# https://corona-api.com/countries/NG
# NG
# https://corona-api.com/countries/NU
# NU
# https://corona-api.com/countries/NF
# NF
# https://corona-api.com/countries/KP
# KP
# https://corona-api.com/countries/MP
# MP
# https://corona-api.com/countries/NO
# NO
# https://corona-api.com/countries/OM
# OM
# https://corona-api.com/countries/PK
# PK
# https://corona-api.com/countries/PW
# PW
# https://corona-api.com/countries/PS
# PS
# https://corona-api.com/countries/PA
# PA
# https://corona-api.com/countries/PG
# PG
# https://corona-api.com/countries/PY
# PY
# https://corona-api.com/countries/PE
# PE
# https://corona-api.com/countries/PH
# PH
# https://corona-api.com/countries/PN
# PN
# https://corona-api.com/countries/PL
# PL
# https://corona-api.com/countries/PT
# PT
# https://corona-api.com/countries/PR
# PR
# https://corona-api.com/countries/QA
# QA
# https://corona-api.com/countries/XK
# XK
# https://corona-api.com/countries/RE
# RE
# https://corona-api.com/countries/RO
# RO
# https://corona-api.com/countries/RU
# RU
# https://corona-api.com/countries/RW
# RW
# https://corona-api.com/countries/BL
# BL
# https://corona-api.com/countries/SH
# SH
# https://corona-api.com/countries/KN
# KN
# https://corona-api.com/countries/LC
# LC
# https://corona-api.com/countries/MF
# MF
# https://corona-api.com/countries/PM
# PM
# https://corona-api.com/countries/VC
# VC
# https://corona-api.com/countries/WS
# WS
# https://corona-api.com/countries/SM
# SM
# https://corona-api.com/countries/ST
# ST
# https://corona-api.com/countries/SA
# SA
# https://corona-api.com/countries/SN
# SN
# https://corona-api.com/countries/RS
# RS
# https://corona-api.com/countries/SC
# SC
# https://corona-api.com/countries/SL
# SL
# https://corona-api.com/countries/SG
# SG
# https://corona-api.com/countries/SX
# SX
# https://corona-api.com/countries/SK
# SK
# https://corona-api.com/countries/SI
# SI
# https://corona-api.com/countries/SB
# SB
# https://corona-api.com/countries/SO
# SO
# https://corona-api.com/countries/ZA
# ZA
# https://corona-api.com/countries/GS
# GS
# https://corona-api.com/countries/KR
# KR
# https://corona-api.com/countries/SS
# SS
# https://corona-api.com/countries/ES
# ES
# https://corona-api.com/countries/LK
# LK
# https://corona-api.com/countries/SD
# SD
# https://corona-api.com/countries/SR
# SR
# https://corona-api.com/countries/SJ
# SJ
# https://corona-api.com/countries/SZ
# SZ
# https://corona-api.com/countries/SE
# SE
# https://corona-api.com/countries/CH
# CH
# https://corona-api.com/countries/SY
# SY
# https://corona-api.com/countries/TW
# TW
# https://corona-api.com/countries/TJ
# TJ
# https://corona-api.com/countries/TZ
# TZ
# https://corona-api.com/countries/TH
# TH
# https://corona-api.com/countries/TL
# TL
# https://corona-api.com/countries/TG
# TG
# https://corona-api.com/countries/TK
# TK
# https://corona-api.com/countries/TO
# TO
# https://corona-api.com/countries/TT
# TT
# https://corona-api.com/countries/TN
# TN
# https://corona-api.com/countries/TR
# TR
# https://corona-api.com/countries/TM
# TM
# https://corona-api.com/countries/TC
# TC
# https://corona-api.com/countries/TV
# TV
# https://corona-api.com/countries/UG
# UG
# https://corona-api.com/countries/UA
# UA
# https://corona-api.com/countries/AE
# AE
# https://corona-api.com/countries/GB
# GB
# https://corona-api.com/countries/US
# US
# https://corona-api.com/countries/UY
# UY
# https://corona-api.com/countries/UZ
# UZ
# https://corona-api.com/countries/VU
# VU
# https://corona-api.com/countries/VE
# VE
# https://corona-api.com/countries/VN
# VN
# https://corona-api.com/countries/WF
# WF
# https://corona-api.com/countries/EH
# EH
# https://corona-api.com/countries/YE
# YE
# https://corona-api.com/countries/ZM
# ZM
# https://corona-api.com/countries/ZW
# ZW
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# '\ndbase[:,0] = country\ndbase[:,1] = code\ndbase[:,2] = date_yesterday\ndbase[:,3] = affected_yesterday\ndbase[:,4] = death_yesterday\ndbase[:,5] = date_today\ndbase[:,6] = affected_today\ndbase[:,7] = death_today\ndbase[:,8] = date_tomorrow\ndbase[:,9] = affected_tomorrow\ndbase[:,10] = death_tomorrow\n'

# %%
connection = psycopg2.connect(user = "zbmdacuv",
                                  password = "IesK82sq2gGKuzffnFdcl3kqcKs5-irT",
                                  host = "arjuna.db.elephantsql.com",
                                  port = "5432",
                                  database = "zbmdacuv")
cursor = connection.cursor()

def getRegion(regID):
    try:
        

       
    # Print PostgreSQL Connection properties
        print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
        cursor.execute("SELECT version();")
        record = cursor.fetchone()
        print("You are connected to - ", record,"\n")
    
        postgres_select_query = "select id from regions where alpha3 = %s"
       
        cursor.execute(postgres_select_query, (regID,))

       # connection.commit()
       # count = cursor.rowcount
       # print (count, "Record inserted successfully into worldprediction table")

    except (Exception, psycopg2.Error) as error :
        if(connection):
            print("Error fetching data from PostgreSQL table", error)
        
    #finally:
    #closing database connection.

# %%
INSERT INTO countryprediction(region_id,alpha_3,country_name, date , affected_1, death_1 , affected_2, death_2 , affected_3, death_3 , prediction_calculation) VALUES( COALESCE ( (SELECT id FROM regions WHERE alpha3 = 'BGD' LIMIT 1) , -1 ) , 'BGD', 'Bangladesh', to_date('16/04/2020', 'DD/MM/YYYY'), 1,2,3,4,5,6,7)

# %%
def insertInfo(regid,alpha3,name,date,affected_1,death_1,affected_2,death_2,affected_3,death_3,pred):
    try:
        postgres_insert_query = """INSERT INTO countryprediction(region_id,alpha_3,country_name, date , affected_1, death_1 , affected_2, death_2 , affected_3, death_3 , prediction_calculation)VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
        cursor.execute(postgres_insert_query, (regid,alpha3,name,date,affected_1,death_1,affected_2,death_2,affected_3,death_3,pred))

        connection.commit()
        count = cursor.rowcount
        print (count, "Record inserted successfully into countryprediction table")
        
    except (Exception, psycopg2.Error) as error :
        if(connection):
            print("Error inserting data in PostgreSQL table", error)

# %%
print(dbase[0:180,:])
# Out:
# [['Afghanistan' 'AFG' '2020-04-17' ... '2020-04-19' 62 3]
#  ['Albania' 'ALB' '2020-04-17' ... '2020-04-19' 22 0]
#  ['Algeria' 'DZA' '2020-04-17' ... '2020-04-19' 163 17]
#  ...
#  ['Yemen' 'YEM' '2020-04-17' ... '2020-04-19' 0 0]
#  ['Zambia' 'ZMB' '2020-04-17' ... '2020-04-19' 3 0]
#  ['Zimbabwe' 'ZWE' '2020-04-17' ... '2020-04-19' 2 0]]

# %%
for j in range(180):
    print(dbase[j])
# Out:
# ['Afghanistan' 'AFG' '2020-04-17' 66 0 '2020-04-18' 66 2 '2020-04-19' 62 3]
# ['Albania' 'ALB' '2020-04-17' 21 0 '2020-04-18' 22 0 '2020-04-19' 22 0]
# ['Algeria' 'DZA' '2020-04-17' 150 16 '2020-04-18' 160 17 '2020-04-19' 163
#  17]
# ['Andorra' 'AND' '2020-04-17' 23 2 '2020-04-18' 16 1 '2020-04-19' 17 1]
# ['Angola' 'AGO' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Antigua and Barbuda' 'ATG' '2020-04-17' 0 0 '2020-04-18' 0 0
#  '2020-04-19' 0 0]
# ['Argentina' 'ARG' '2020-04-17' 98 8 '2020-04-18' 126 7 '2020-04-19' 123 7]
# ['Armenia' 'ARM' '2020-04-17' 42 1 '2020-04-18' 45 1 '2020-04-19' 45 1]
# ['Australia' 'AUS' '2020-04-17' 60 3 '2020-04-18' 43 1 '2020-04-19' 49 2]
# ['Austria' 'AUT' '2020-04-17' 119 21 '2020-04-18' 129 22 '2020-04-19' 131
#  22]
# ['Azerbaijan' 'AZE' '2020-04-17' 57 0 '2020-04-18' 53 1 '2020-04-19' 52 1]
# ['Bahamas' 'BHS' '2020-04-17' 1 1 '2020-04-18' 2 0 '2020-04-19' 2 0]
# ['Bahrain' 'BHR' '2020-04-17' 40 0 '2020-04-18' 72 0 '2020-04-19' 81 0]
# ['Bangladesh' 'BGD' '2020-04-17' 266 15 '2020-04-18' 299 16 '2020-04-19'
#  308 16]
# ['Barbados' 'BRB' '2020-04-17' 0 0 '2020-04-18' 1 0 '2020-04-19' 1 0]
# ['Belarus' 'BLR' '2020-04-17' 575 2 '2020-04-18' 599 3 '2020-04-19' 605 3]
# ['Belgium' 'BEL' '2020-04-17' 1329 306 '2020-04-18' 1691 362 '2020-04-19'
#  1782 372]
# ['Belize' 'BLZ' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Benin' 'BEN' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Bhutan' 'BTN' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Bolivia (Plurinational State of)' 'BOL' '2020-04-17' 24 2 '2020-04-18'
#  37 2 '2020-04-19' 37 2]
# ['Bosnia and Herzegovina' 'BIH' '2020-04-17' 47 3 '2020-04-18' 49 3
#  '2020-04-19' 51 3]
# ['Botswana' 'BWA' '2020-04-17' 0 0 '2020-04-18' 1 0 '2020-04-19' 1 0]
# ['Brazil' 'BRA' '2020-04-17' 3257 217 '2020-04-18' 3037 208 '2020-04-19'
#  3030 210]
# ['Brunei Darussalam' 'BRN' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19'
#  0 0]
# ['Bulgaria' 'BGR' '2020-04-17' 46 3 '2020-04-18' 48 3 '2020-04-19' 49 3]
# ['Burkina Faso' 'BFA' '2020-04-17' 11 3 '2020-04-18' 11 2 '2020-04-19' 11
#  2]
# ['Burundi' 'BDI' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Cambodia' 'KHM' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Cameroon' 'CMR' '2020-04-17' 0 0 '2020-04-18' 78 3 '2020-04-19' 91 3]
# ['Canada' 'CAN' '2020-04-17' 2005 97 '2020-04-18' 2211 180 '2020-04-19'
#  2313 192]
# ['Cabo Verde' 'CPV' '2020-04-17' 0 0 '2020-04-18' 15 0 '2020-04-19' 5 0]
# ['Central African Republic' 'CAF' '2020-04-17' 0 0 '2020-04-18' 0 0
#  '2020-04-19' 0 0]
# ['Chad' 'TCD' '2020-04-17' 0 0 '2020-04-18' 2 0 '2020-04-19' 2 0]
# ['Chile' 'CHL' '2020-04-17' 445 11 '2020-04-18' 480 8 '2020-04-19' 493 10]
# ['China' 'CHN' '2020-04-17' 357 1290 '2020-04-18' 213 688 '2020-04-19' 267
#  917]
# ['Colombia' 'COL' '2020-04-17' 206 9 '2020-04-18' 225 10 '2020-04-19' 230
#  11]
# ['Congo' 'COG' '2020-04-17' 26 1 '2020-04-18' 32 0 '2020-04-19' 34 0]
# ['Congo (Democratic Republic of the)' 'COD' '2020-04-17' 20 1 '2020-04-18'
#  15 1 '2020-04-19' 17 1]
# ['Costa Rica' 'CRI' '2020-04-17' 7 0 '2020-04-18' 11 0 '2020-04-19' 12 0]
# ['Croatia' 'HRV' '2020-04-17' 23 1 '2020-04-18' 39 1 '2020-04-19' 40 1]
# ['Cuba' 'CUB' '2020-04-17' 61 4 '2020-04-18' 52 3 '2020-04-19' 56 3]
# ['Cyprus' 'CYP' '2020-04-17' 15 0 '2020-04-18' 18 0 '2020-04-19' 18 0]
# ['Czech Republic' 'CZE' '2020-04-17' 116 4 '2020-04-18' 168 4 '2020-04-19'
#  177 4]
# ['Denmark' 'DNK' '2020-04-17' 194 15 '2020-04-18' 192 15 '2020-04-19' 195
#  15]
# ['Djibouti' 'DJI' '2020-04-17' 141 0 '2020-04-18' 139 0 '2020-04-19' 146 0]
# ['Dominica' 'DMA' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Dominican Republic' 'DOM' '2020-04-17' 371 4 '2020-04-18' 326 5
#  '2020-04-19' 325 5]
# ['Ecuador' 'ECU' '2020-04-17' 225 18 '2020-04-18' 304 17 '2020-04-19' 314
#  17]
# ['Egypt' 'EGY' '2020-04-17' 171 9 '2020-04-18' 171 10 '2020-04-19' 171 11]
# ['El Salvador' 'SLV' '2020-04-17' 13 1 '2020-04-18' 10 0 '2020-04-19' 11 0]
# ['Equatorial Guinea' 'GNQ' '2020-04-17' 28 0 '2020-04-18' 18 0
#  '2020-04-19' 21 0]
# ['Eritrea' 'ERI' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Estonia' 'EST' '2020-04-17' 25 2 '2020-04-18' 30 2 '2020-04-19' 30 2]
# ['Ethiopia' 'ETH' '2020-04-17' 4 0 '2020-04-18' 5 0 '2020-04-19' 5 0]
# ['Fiji' 'FJI' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Finland' 'FIN' '2020-04-17' 120 7 '2020-04-18' 120 6 '2020-04-19' 124 6]
# ['France' 'FRA' '2020-04-17' 2039 762 '2020-04-18' 7780 986 '2020-04-19'
#  8591 1043]
# ['Gabon' 'GAB' '2020-04-17' 28 0 '2020-04-18' 22 0 '2020-04-19' 22 0]
# ['Gambia' 'GMB' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Georgia' 'GEO' '2020-04-17' 22 0 '2020-04-18' 30 0 '2020-04-19' 33 0]
# ['Germany' 'DEU' '2020-04-17' 3699 300 '2020-04-18' 3496 363 '2020-04-19'
#  3531 378]
# ['Ghana' 'GHA' '2020-04-17' 0 0 '2020-04-18' 2 0 '2020-04-19' 3 0]
# ['Greece' 'GRC' '2020-04-17' 17 3 '2020-04-18' 18 2 '2020-04-19' 18 2]
# ['Grenada' 'GRD' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Guatemala' 'GTM' '2020-04-17' 18 2 '2020-04-18' 18 0 '2020-04-19' 18 1]
# ['Guinea' 'GIN' '2020-04-17' 39 2 '2020-04-18' 39 1 '2020-04-19' 37 1]
# ['Guinea-Bissau' 'GNB' '2020-04-17' 0 0 '2020-04-18' 1 0 '2020-04-19' 0 0]
# ['Guyana' 'GUY' '2020-04-17' 8 0 '2020-04-18' 6 0 '2020-04-19' 6 0]
# ['Haiti' 'HTI' '2020-04-17' 2 0 '2020-04-18' 1 0 '2020-04-19' 1 0]
# ['Holy See' 'VAT' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Honduras' 'HND' '2020-04-17' 16 6 '2020-04-18' 13 5 '2020-04-19' 13 5]
# ['Hungary' 'HUN' '2020-04-17' 111 14 '2020-04-18' 120 12 '2020-04-19' 122
#  12]
# ['Iceland' 'ISL' '2020-04-17' 15 1 '2020-04-18' 15 0 '2020-04-19' 15 0]
# ['India' 'IND' '2020-04-17' 922 38 '2020-04-18' 1009 37 '2020-04-19' 1030
#  39]
# ['Indonesia' 'IDN' '2020-04-17' 407 24 '2020-04-18' 413 23 '2020-04-19'
#  415 25]
# ["Côte d'Ivoire" 'CIV' '2020-04-17' 34 0 '2020-04-18' 38 0 '2020-04-19' 39
#  0]
# ['Iran (Islamic Republic of)' 'IRN' '2020-04-17' 1499 89 '2020-04-18' 1557
#  91 '2020-04-19' 1566 91]
# ['Iraq' 'IRQ' '2020-04-17' 48 1 '2020-04-18' 55 1 '2020-04-19' 57 1]
# ['Ireland' 'IRL' '2020-04-17' 709 44 '2020-04-18' 858 44 '2020-04-19' 793
#  44]
# ['Israel' 'ISR' '2020-04-17' 224 9 '2020-04-18' 320 10 '2020-04-19' 286 10]
# ['Italy' 'ITA' '2020-04-17' 3493 575 '2020-04-18' 3539 569 '2020-04-19'
#  3615 566]
# ['Jamaica' 'JAM' '2020-04-17' 0 0 '2020-04-18' 21 0 '2020-04-19' 17 0]
# ['Japan' 'JPN' '2020-04-17' 1161 12 '2020-04-18' 1319 21 '2020-04-19' 1359
#  23]
# ['Jordan' 'JOR' '2020-04-17' 5 0 '2020-04-18' 4 0 '2020-04-19' 4 0]
# ['Kazakhstan' 'KAZ' '2020-04-17' 144 0 '2020-04-18' 153 0 '2020-04-19' 155
#  0]
# ['Kenya' 'KEN' '2020-04-17' 12 0 '2020-04-18' 10 0 '2020-04-19' 10 0]
# ['Kuwait' 'KWT' '2020-04-17' 134 2 '2020-04-18' 137 0 '2020-04-19' 138 1]
# ['Kyrgyzstan' 'KGZ' '2020-04-17' 23 0 '2020-04-18' 20 0 '2020-04-19' 21 0]
# ["Lao People's Democratic Republic" 'LAO' '2020-04-17' 0 0 '2020-04-18' 0
#  0 '2020-04-19' 0 0]
# ['Latvia' 'LVA' '2020-04-17' 7 0 '2020-04-18' 8 0 '2020-04-19' 8 0]
# ['Lebanon' 'LBN' '2020-04-17' 5 0 '2020-04-18' 9 0 '2020-04-19' 6 0]
# ['Liberia' 'LBR' '2020-04-17' 17 1 '2020-04-18' 5 0 '2020-04-19' 10 0]
# ['Libya' 'LBY' '2020-04-17' 0 0 '2020-04-18' 5 0 '2020-04-19' 3 0]
# ['Liechtenstein' 'LIE' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Lithuania' 'LTU' '2020-04-17' 21 1 '2020-04-18' 29 1 '2020-04-19' 30 1]
# ['Luxembourg' 'LUX' '2020-04-17' 36 3 '2020-04-18' 58 2 '2020-04-19' 59 2]
# ['Macedonia (the former Yugoslav Republic of)' 'MKD' '2020-04-17' 36 3
#  '2020-04-18' 77 1 '2020-04-19' 81 2]
# ['Madagascar' 'MDG' '2020-04-17' 6 0 '2020-04-18' 4 0 '2020-04-19' 4 0]
# ['Malawi' 'MWI' '2020-04-17' 1 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Malaysia' 'MYS' '2020-04-17' 69 2 '2020-04-18' 93 1 '2020-04-19' 95 1]
# ['Maldives' 'MDV' '2020-04-17' 3 0 '2020-04-18' 2 0 '2020-04-19' 2 0]
# ['Mali' 'MLI' '2020-04-17' 0 0 '2020-04-18' 12 0 '2020-04-19' 14 0]
# ['Malta' 'MLT' '2020-04-17' 10 0 '2020-04-18' 11 0 '2020-04-19' 11 0]
# ['Mauritania' 'MRT' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Mauritius' 'MUS' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Mexico' 'MEX' '2020-04-17' 450 37 '2020-04-18' 450 52 '2020-04-19' 450
#  47]
# ['Moldova (Republic of)' 'MDA' '2020-04-17' 110 2 '2020-04-18' 111 5
#  '2020-04-19' 111 5]
# ['Monaco' 'MCO' '2020-04-17' 1 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Mongolia' 'MNG' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Montenegro' 'MNE' '2020-04-17' 0 1 '2020-04-18' 8 0 '2020-04-19' 9 0]
# ['Morocco' 'MAR' '2020-04-17' 281 5 '2020-04-18' 286 5 '2020-04-19' 287 5]
# ['Mozambique' 'MOZ' '2020-04-17' 3 0 '2020-04-18' 3 0 '2020-04-19' 3 0]
# ['Namibia' 'NAM' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Nepal' 'NPL' '2020-04-17' 14 0 '2020-04-18' 4 0 '2020-04-19' 9 0]
# ['Netherlands' 'NLD' '2020-04-17' 1236 144 '2020-04-18' 1278 163
#  '2020-04-19' 1288 166]
# ['New Zealand' 'NZL' '2020-04-17' 8 2 '2020-04-18' 13 0 '2020-04-19' 13 1]
# ['Nicaragua' 'NIC' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Niger' 'NER' '2020-04-17' 43 4 '2020-04-18' 27 1 '2020-04-19' 32 2]
# ['Nigeria' 'NGA' '2020-04-17' 51 4 '2020-04-18' 55 2 '2020-04-19' 56 2]
# ['Norway' 'NOR' '2020-04-17' 41 9 '2020-04-18' 112 8 '2020-04-19' 117 7]
# ['Oman' 'OMN' '2020-04-17' 50 2 '2020-04-18' 87 0 '2020-04-19' 89 1]
# ['Pakistan' 'PAK' '2020-04-17' 106 7 '2020-04-18' 289 13 '2020-04-19' 347
#  13]
# ['Panama' 'PAN' '2020-04-17' 265 6 '2020-04-18' 287 6 '2020-04-19' 292 6]
# ['Papua New Guinea' 'PNG' '2020-04-17' 0 0 '2020-04-18' 2 0 '2020-04-19' 3
#  0]
# ['Paraguay' 'PRY' '2020-04-17' 25 0 '2020-04-18' 28 0 '2020-04-19' 28 0]
# ['Peru' 'PER' '2020-04-17' 998 26 '2020-04-18' 1070 24 '2020-04-19' 1042
#  24]
# ['Philippines' 'PHL' '2020-04-17' 218 25 '2020-04-18' 220 19 '2020-04-19'
#  221 21]
# ['Poland' 'POL' '2020-04-17' 461 18 '2020-04-18' 417 24 '2020-04-19' 429
#  24]
# ['Portugal' 'PRT' '2020-04-17' 181 28 '2020-04-18' 546 29 '2020-04-19' 565
#  29]
# ['Qatar' 'QAT' '2020-04-17' 560 0 '2020-04-18' 602 0 '2020-04-19' 612 0]
# ['Romania' 'ROU' '2020-04-17' 360 19 '2020-04-18' 426 19 '2020-04-19' 439
#  19]
# ['Russian Federation' 'RUS' '2020-04-17' 4070 41 '2020-04-18' 4225 42
#  '2020-04-19' 4264 43]
# ['Rwanda' 'RWA' '2020-04-17' 5 0 '2020-04-18' 3 0 '2020-04-19' 3 0]
# ['Saint Kitts and Nevis' 'KNA' '2020-04-17' 0 0 '2020-04-18' 0 0
#  '2020-04-19' 0 0]
# ['Saint Lucia' 'LCA' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Saint Vincent and the Grenadines' 'VCT' '2020-04-17' 0 0 '2020-04-18' 0
#  0 '2020-04-19' 0 0]
# ['San Marino' 'SMR' '2020-04-17' 9 1 '2020-04-18' 31 1 '2020-04-19' 36 1]
# ['Sao Tome and Principe' 'STP' '2020-04-17' 0 0 '2020-04-18' 0 0
#  '2020-04-19' 0 0]
# ['Saudi Arabia' 'SAU' '2020-04-17' 762 4 '2020-04-18' 823 4 '2020-04-19'
#  838 4]
# ['Senegal' 'SEN' '2020-04-17' 7 0 '2020-04-18' 15 0 '2020-04-19' 16 0]
# ['Serbia' 'SRB' '2020-04-17' 372 7 '2020-04-18' 415 5 '2020-04-19' 419 6]
# ['Seychelles' 'SYC' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Sierra Leone' 'SLE' '2020-04-17' 11 0 '2020-04-18' 5 0 '2020-04-19' 7 0]
# ['Singapore' 'SGP' '2020-04-17' 623 1 '2020-04-18' 655 0 '2020-04-19' 675
#  0]
# ['Slovakia' 'SVK' '2020-04-17' 72 1 '2020-04-18' 88 2 '2020-04-19' 94 2]
# ['Slovenia' 'SVN' '2020-04-17' 36 5 '2020-04-18' 31 4 '2020-04-19' 32 4]
# ['Somalia' 'SOM' '2020-04-17' 36 1 '2020-04-18' 25 1 '2020-04-19' 27 1]
# ['South Africa' 'ZAF' '2020-04-17' 178 2 '2020-04-18' 197 9 '2020-04-19'
#  202 9]
# ['Korea (Republic of)' 'KOR' '2020-04-17' 22 1 '2020-04-18' 23 2
#  '2020-04-19' 22 2]
# ['South Sudan' 'SSD' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Spain' 'ESP' '2020-04-17' 5891 687 '2020-04-18' 6539 664 '2020-04-19'
#  6707 668]
# ['Sri Lanka' 'LKA' '2020-04-17' 6 0 '2020-04-18' 4 0 '2020-04-19' 4 0]
# ['Sudan' 'SDN' '2020-04-17' 1 1 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Suriname' 'SUR' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Swaziland' 'SWZ' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Sweden' 'SWE' '2020-04-17' 676 67 '2020-04-18' 691 109 '2020-04-19' 695
#  110]
# ['Switzerland' 'CHE' '2020-04-17' 346 46 '2020-04-18' 368 51 '2020-04-19'
#  374 53]
# ['Syrian Arab Republic' 'SYR' '2020-04-17' 5 0 '2020-04-18' 4 0
#  '2020-04-19' 4 0]
# ['Taiwan' 'TWN' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Tanzania, United Republic of' 'TZA' '2020-04-17' 53 1 '2020-04-18' 40 0
#  '2020-04-19' 42 0]
# ['Thailand' 'THA' '2020-04-17' 28 1 '2020-04-18' 28 2 '2020-04-19' 28 2]
# ['Timor-Leste' 'TLS' '2020-04-17' 0 0 '2020-04-18' 5 0 '2020-04-19' 6 0]
# ['Togo' 'TGO' '2020-04-17' 2 0 '2020-04-18' 2 1 '2020-04-19' 2 1]
# ['Trinidad and Tobago' 'TTO' '2020-04-17' 0 0 '2020-04-18' 0 0
#  '2020-04-19' 0 0]
# ['Tunisia' 'TUN' '2020-04-17' 42 0 '2020-04-18' 39 1 '2020-04-19' 41 1]
# ['Turkey' 'TUR' '2020-04-17' 4353 126 '2020-04-18' 4582 126 '2020-04-19'
#  4624 126]
# ['Uganda' 'UGA' '2020-04-17' 1 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Ukraine' 'UKR' '2020-04-17' 501 9 '2020-04-18' 527 9 '2020-04-19' 533 9]
# ['United Arab Emirates' 'ARE' '2020-04-17' 477 2 '2020-04-18' 481 3
#  '2020-04-19' 482 2]
# ['United Kingdom of Great Britain and Northern Ireland' 'GBR' '2020-04-17'
#  5624 848 '2020-04-18' 5864 846 '2020-04-19' 5924 853]
# ['United States of America' 'USA' '2020-04-17' 31905 3856 '2020-04-18'
#  32018 4066 '2020-04-19' 32046 4213]
# ['Uruguay' 'URY' '2020-04-17' 0 0 '2020-04-18' 6 0 '2020-04-19' 6 0]
# ['Uzbekistan' 'UZB' '2020-04-17' 56 0 '2020-04-18' 81 0 '2020-04-19' 88 0]
# ['Venezuela (Bolivarian Republic of)' 'VEN' '2020-04-17' 0 0 '2020-04-18'
#  3 0 '2020-04-19' 4 0]
# ['Viet Nam' 'VNM' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Western Sahara' 'ESH' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Yemen' 'YEM' '2020-04-17' 0 0 '2020-04-18' 0 0 '2020-04-19' 0 0]
# ['Zambia' 'ZMB' '2020-04-17' 4 0 '2020-04-18' 3 0 '2020-04-19' 3 0]
# ['Zimbabwe' 'ZWE' '2020-04-17' 1 0 '2020-04-18' 2 0 '2020-04-19' 2 0]

# %%
regid=[]
for i in range(180):
    regid=getRegion(dbase[i][1])
    insertInfo(regid,dbase[i][1],dbase[i][0],dbase[i][2],dbase[i][3],dbase[i][4],dbase[i][6],dbase[i][7],dbase[i][9],dbase[i][10],0)
    print(i)

if(connection):
    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
# Out:
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 0
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 1
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 2
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 3
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 4
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 5
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 6
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 7
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 8
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 9
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 10
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 11
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 12
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 13
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 14
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 15
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 16
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 17
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 18
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 19
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 20
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 21
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 22
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 23
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 24
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 25
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 26
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 27
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 28
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 29
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 30
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 31
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 32
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 33
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 34
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 35
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
# 1 Record inserted successfully into countryprediction table
# 36
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 37
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 38
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 39
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 40
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 41
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 42
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 43
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 44
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 45
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 46
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 47
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 48
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 49
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 50
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 51
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 52
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 53
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 54
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 55
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 56
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 57
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 58
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 59
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 60
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 61
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 62
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 63
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 64
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 65
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 66
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 67
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 68
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 69
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 70
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 71
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 72
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
# 1 Record inserted successfully into countryprediction table
# 73
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 74
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 75
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 76
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 77
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 78
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 79
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 80
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 81
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 82
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 83
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 84
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 85
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 86
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 87
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 88
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 89
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 90
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 91
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 92
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 93
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 94
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 95
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 96
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 97
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 98
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 99
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 100
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 101
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 102
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 103
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 104
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 105
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# ...
#
# 1 Record inserted successfully into countryprediction table
# 144
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 145
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 146
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
# 1 Record inserted successfully into countryprediction table
# 147
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 148
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 149
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 150
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 151
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 152
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 153
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 154
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 155
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 156
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 157
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 158
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 159
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 160
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 161
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 162
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 163
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 164
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 165
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 166
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 167
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 168
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 169
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 170
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 171
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 172
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 173
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 174
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 175
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 176
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 177
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 178
# {'user': 'zbmdacuv', 'dbname': 'zbmdacuv', 'host': 'arjuna.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg18.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0, 64-bit',)
#
# 1 Record inserted successfully into countryprediction table
# 179
# PostgreSQL connection is closed

# %%
try:
    
    connection = psycopg2.connect(user = "zbmdacuv",
                                  password = "IesK82sq2gGKuzffnFdcl3kqcKs5-irT",
                                  host = "arjuna.db.elephantsql.com",
                                  port = "5432",
                                  database = "zbmdacuv")
    cursor = connection.cursor()
    postgres_select_query2 = "select affected_1 from countryprediction where country_name = %s"
    rec = 'Bangladesh'
    cursor.execute(postgres_select_query2,(rec,) )
    shoytan = cursor.fetchall()
    for r in shoytan :
        print(r[0])

except (Exception, psycopg2.Error) as error :
        if(connection):
            print("Error fetching data from PostgreSQL table", error)
finally:
    if(connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# 341
# PostgreSQL connection is closed

# %%
dbase[:,0:4]
# Out:
# array([['Afghanistan', 'AFG', '2020-04-16', 56],
#        ['Albania', 'ALB', '2020-04-16', 24],
#        ['Algeria', 'DZA', '2020-04-16', 108],
#        ['Andorra', 'AND', '2020-04-16', 0],
#        ['Angola', 'AGO', '2020-04-16', 0],
#        ['Antigua and Barbuda', 'ATG', '2020-04-16', 0],
#        ['Argentina', 'ARG', '2020-04-16', 128],
#        ['Armenia', 'ARM', '2020-04-16', 48],
#        ['Australia', 'AUS', '2020-04-16', 22],
#        ['Austria', 'AUT', '2020-04-16', 140],
#        ['Azerbaijan', 'AZE', '2020-04-16', 30],
#        ['Bahamas', 'BHS', '2020-04-16', 4],
#        ['Bahrain', 'BHR', '2020-04-16', 29],
#        ['Bangladesh', 'BGD', '2020-04-16', 341],
#        ['Barbados', 'BRB', '2020-04-16', 2],
#        ['Belarus', 'BLR', '2020-04-16', 476],
#        ['Belgium', 'BEL', '2020-04-16', 1236],
#        ['Belize', 'BLZ', '2020-04-16', 0],
#        ['Benin', 'BEN', '2020-04-16', 0],
#        ['Bhutan', 'BTN', '2020-04-16', 0],
#        ['Bolivia (Plurinational State of)', 'BOL', '2020-04-16', 44],
#        ['Bosnia and Herzegovina', 'BIH', '2020-04-16', 57],
#        ['Brazil', 'BRA', '2020-04-16', 2105],
#        ['Brunei Darussalam', 'BRN', '2020-04-16', 0],
#        ['Bulgaria', 'BGR', '2020-04-16', 53],
#        ['Burkina Faso', 'BFA', '2020-04-16', 4],
#        ['Burundi', 'BDI', '2020-04-16', 0],
#        ['Cambodia', 'KHM', '2020-04-16', 0],
#        ['Cameroon', 'CMR', '2020-04-16', 148],
#        ['Canada', 'CAN', '2020-04-16', 2600],
#        ['Cabo Verde', 'CPV', '2020-04-16', 0],
#        ['Central African Republic', 'CAF', '2020-04-16', 0],
#        ['Chad', 'TCD', '2020-04-16', 4],
#        ['Chile', 'CHL', '2020-04-16', 534],
#        ['China', 'CHN', '2020-04-16', 47],
#        ['Colombia', 'COL', '2020-04-16', 128],
#        ['Congo', 'COG', '2020-04-16', 0],
#        ['Congo (Democratic Republic of the)', 'COD', '2020-04-16', 13],
#        ['Costa Rica', 'CRI', '2020-04-16', 16],
#        ['Croatia', 'HRV', '2020-04-16', 50],
#        ['Cuba', 'CUB', '2020-04-16', 48],
#        ['Cyprus', 'CYP', '2020-04-16', 20],
#        ['Czech Republic', 'CZE', '2020-04-16', 217],
#        ['Denmark', 'DNK', '2020-04-16', 198],
#        ['Djibouti', 'DJI', '2020-04-16', 156],
#        ['Dominica', 'DMA', '2020-04-16', 0],
#        ['Dominican Republic', 'DOM', '2020-04-16', 141],
#        ['Ecuador', 'ECU', '2020-04-16', 367],
#        ['Egypt', 'EGY', '2020-04-16', 168],
#        ['El Salvador', 'SLV', '2020-04-16', 5],
#        ['Equatorial Guinea', 'GNQ', '2020-04-16', 0],
#        ['Eritrea', 'ERI', '2020-04-16', 0],
#        ['Estonia', 'EST', '2020-04-16', 34],
#        ['Ethiopia', 'ETH', '2020-04-16', 7],
#        ['Fiji', 'FJI', '2020-04-16', 1],
#        ['Finland', 'FIN', '2020-04-16', 132],
#        ['France', 'FRA', '2020-04-16', 12509],
#        ['Gabon', 'GAB', '2020-04-16', 0],
#        ['Gambia', 'GMB', '2020-04-16', 0],
#        ['Georgia', 'GEO', '2020-04-16', 42],
#        ['Germany', 'DEU', '2020-04-16', 2945],
#        ['Ghana', 'GHA', '2020-04-16', 5],
#        ['Greece', 'GRC', '2020-04-16', 15],
#        ['Grenada', 'GRD', '2020-04-16', 0],
#        ['Guatemala', 'GTM', '2020-04-16', 16],
#        ['Guinea', 'GIN', '2020-04-16', 34],
#        ['Guinea-Bissau', 'GNB', '2020-04-16', 0],
#        ['Guyana', 'GUY', '2020-04-16', 0],
#        ['Haiti', 'HTI', '2020-04-16', 0],
#        ['Holy See', 'VAT', '2020-04-16', 0],
#        ['Honduras', 'HND', '2020-04-16', 7],
#        ['Hungary', 'HUN', '2020-04-16', 73],
#        ['Iceland', 'ISL', '2020-04-16', 12],
#        ['India', 'IND', '2020-04-16', 1108],
#        ['Indonesia', 'IDN', '2020-04-16', 380],
#        ["Côte d'Ivoire", 'CIV', '2020-04-16', 16],
#        ['Iran (Islamic Republic of)', 'IRN', '2020-04-16', 1606],
#        ['Iraq', 'IRQ', '2020-04-16', 19],
#        ['Ireland', 'IRL', '2020-04-16', 724],
#        ['Israel', 'ISR', '2020-04-16', 257],
#        ['Italy', 'ITA', '2020-04-16', 3786],
#        ['Jamaica', 'JAM', '2020-04-16', 18],
#        ['Japan', 'JPN', '2020-04-16', 526],
#        ['Jordan', 'JOR', '2020-04-16', 1],
#        ['Kazakhstan', 'KAZ', '2020-04-16', 107],
#        ['Kenya', 'KEN', '2020-04-16', 9],
#        ['Kuwait', 'KWT', '2020-04-16', 119],
#        ['Kyrgyzstan', 'KGZ', '2020-04-16', 17],
#        ["Lao People's Democratic Republic", 'LAO', '2020-04-16', 0],
#        ['Latvia', 'LVA', '2020-04-16', 9],
#        ['Lebanon', 'LBN', '2020-04-16', 5],
#        ['Liberia', 'LBR', '2020-04-16', 0],
#        ['Libya', 'LBY', '2020-04-16', 1],
#        ['Liechtenstein', 'LIE', '2020-04-16', 0],
#        ['Lithuania', 'LTU', '2020-04-16', 37],
#        ['Luxembourg', 'LUX', '2020-04-16', 71],
#        ['Macedonia (the former Yugoslav Republic of)', 'MKD',
#         '2020-04-16', 107],
#        ['Madagascar', 'MDG', '2020-04-16', 1],
#        ['Malawi', 'MWI', '2020-04-16', 0],
#        ['Malaysia', 'MYS', '2020-04-16', 110],
#        ['Maldives', 'MDV', '2020-04-16', 3],
#        ['Mali', 'MLI', '2020-04-16', 23],
#        ['Malta', 'MLT', '2020-04-16', 13],
#        ['Mauritania', 'MRT', '2020-04-16', 0],
#        ['Mauritius', 'MUS', '2020-04-16', 0],
#        ['Mexico', 'MEX', '2020-04-16', 448],
#        ['Moldova (Republic of)', 'MDA', '2020-04-16', 105],
#        ['Monaco', 'MCO', '2020-04-16', 0],
#        ['Mongolia', 'MNG', '2020-04-16', 1],
#        ['Montenegro', 'MNE', '2020-04-16', 15],
#        ['Morocco', 'MAR', '2020-04-16', 259],
#        ['Mozambique', 'MOZ', '2020-04-16', 2],
#        ['Namibia', 'NAM', '2020-04-16', 0],
#        ['Nepal', 'NPL', '2020-04-16', 0],
#        ['Netherlands', 'NLD', '2020-04-16', 1067],
#        ['New Zealand', 'NZL', '2020-04-16', 15],
#        ['Nicaragua', 'NIC', '2020-04-16', 0],
#        ['Niger', 'NER', '2020-04-16', 0],
#        ['Nigeria', 'NGA', '2020-04-16', 35],
#        ['Norway', 'NOR', '2020-04-16', 156],
#        ['Oman', 'OMN', '2020-04-16', 109],
#        ['Pakistan', 'PAK', '2020-04-16', 536],
#        ['Panama', 'PAN', '2020-04-16', 177],
#        ['Papua New Guinea', 'PNG', '2020-04-16', 5],
#        ['Paraguay', 'PRY', '2020-04-16', 13],
#        ['Peru', 'PER', '2020-04-16', 1016],
#        ['Philippines', 'PHL', '2020-04-16', 207],
#        ['Poland', 'POL', '2020-04-16', 336],
#        ['Portugal', 'PRT', '2020-04-16', 750],
#        ['Qatar', 'QAT', '2020-04-16', 392],
#        ['Romania', 'ROU', '2020-04-16', 491],
#        ['Russian Federation', 'RUS', '2020-04-16', 3448],
#        ['Rwanda', 'RWA', '2020-04-16', 2],
#        ['Saint Kitts and Nevis', 'KNA', '2020-04-16', 0],
#        ['Saint Lucia', 'LCA', '2020-04-16', 0],
#        ['Saint Vincent and the Grenadines', 'VCT', '2020-04-16', 0],
#        ['San Marino', 'SMR', '2020-04-16', 54],
#        ['Sao Tome and Principe', 'STP', '2020-04-16', 0],
#        ['Saudi Arabia', 'SAU', '2020-04-16', 518],
#        ['Senegal', 'SEN', '2020-04-16', 21],
#        ['Serbia', 'SRB', '2020-04-16', 445],
#        ['Seychelles', 'SYC', '2020-04-16', 0],
#        ['Sierra Leone', 'SLE', '2020-04-16', 2],
#        ['Singapore', 'SGP', '2020-04-16', 728],
#        ['Slovakia', 'SVK', '2020-04-16', 114],
#        ['Slovenia', 'SVN', '2020-04-16', 20],
#        ['Somalia', 'SOM', '2020-04-16', 0],
#        ['South Africa', 'ZAF', '2020-04-16', 99],
#        ['Korea (Republic of)', 'KOR', '2020-04-16', 22],
#        ['South Sudan', 'SSD', '2020-04-16', 0],
#        ['Spain', 'ESP', '2020-04-16', 7304],
#        ['Sri Lanka', 'LKA', '2020-04-16', 0],
#        ['Sudan', 'SDN', '2020-04-16', 0],
#        ['Suriname', 'SUR', '2020-04-16', 0],
#        ['Swaziland', 'SWZ', '2020-04-16', 1],
#        ['Sweden', 'SWE', '2020-04-16', 613],
#        ['Switzerland', 'CHE', '2020-04-16', 396],
#        ['Syrian Arab Republic', 'SYR', '2020-04-16', 0],
#        ['Taiwan', 'TWN', '2020-04-16', 0],
#        ['Tanzania, United Republic of', 'TZA', '2020-04-16', 6],
#        ['Thailand', 'THA', '2020-04-16', 29],
#        ['Timor-Leste', 'TLS', '2020-04-16', 10],
#        ['Togo', 'TGO', '2020-04-16', 0],
#        ['Trinidad and Tobago', 'TTO', '2020-04-16', 0],
#        ['Tunisia', 'TUN', '2020-04-16', 42],
#        ['Turkey', 'TUR', '2020-04-16', 4801],
#        ['Uganda', 'UGA', '2020-04-16', 0],
#        ['Ukraine', 'UKR', '2020-04-16', 397],
#        ['United Arab Emirates', 'ARE', '2020-04-16', 460],
#        ['United Kingdom of Great Britain and Northern Ireland', 'GBR',
#         '2020-04-16', 4662],
#        ['United States of America', 'USA', '2020-04-16', 31451],
#        ['Uruguay', 'URY', '2020-04-16', 10],
#        ['Uzbekistan', 'UZB', '2020-04-16', 47],
#        ['Venezuela (Bolivarian Republic of)', 'VEN', '2020-04-16', 7],
#        ['Viet Nam', 'VNM', '2020-04-16', 1],
#        ['Western Sahara', 'ESH', '2020-04-16', 0],
#        ['Yemen', 'YEM', '2020-04-16', 0],
#        ['Zambia', 'ZMB', '2020-04-16', 0],
#        ['Zimbabwe', 'ZWE', '2020-04-16', 0],
#        ['Angola', 'AGO', '2020-03-27', 0]], dtype=object)

# %%
dbase[0][1]
# Out:
# 'ALB'

# %%
tempbase = np.hstack((dbase[:,:1],dbase[:,5:6]))
tempbase = np.hstack((tempbase,dbase[:,6:7]))
tempbase = np.hstack((tempbase,dbase[:,7:8]))

# %%
len(tempbase)
# Out:
# 180

# %%
print(tempbase)
# Out:
# [['Afghanistan' '2020-04-18' 66 2]
#  ['Albania' '2020-04-18' 22 0]
#  ['Algeria' '2020-04-18' 160 17]
#  ['Andorra' '2020-04-18' 16 1]
#  ['Angola' '2020-04-18' 0 0]
#  ['Antigua and Barbuda' '2020-04-18' 0 0]
#  ['Argentina' '2020-04-18' 126 7]
#  ['Armenia' '2020-04-18' 45 1]
#  ['Australia' '2020-04-18' 43 1]
#  ['Austria' '2020-04-18' 129 22]
#  ['Azerbaijan' '2020-04-18' 53 1]
#  ['Bahamas' '2020-04-18' 2 0]
#  ['Bahrain' '2020-04-18' 72 0]
#  ['Bangladesh' '2020-04-18' 299 16]
#  ['Barbados' '2020-04-18' 1 0]
#  ['Belarus' '2020-04-18' 599 3]
#  ['Belgium' '2020-04-18' 1691 362]
#  ['Belize' '2020-04-18' 0 0]
#  ['Benin' '2020-04-18' 0 0]
#  ['Bhutan' '2020-04-18' 0 0]
#  ['Bolivia (Plurinational State of)' '2020-04-18' 37 2]
#  ['Bosnia and Herzegovina' '2020-04-18' 49 3]
#  ['Botswana' '2020-04-18' 1 0]
#  ['Brazil' '2020-04-18' 3037 208]
#  ['Brunei Darussalam' '2020-04-18' 0 0]
#  ['Bulgaria' '2020-04-18' 48 3]
#  ['Burkina Faso' '2020-04-18' 11 2]
#  ['Burundi' '2020-04-18' 0 0]
#  ['Cambodia' '2020-04-18' 0 0]
#  ['Cameroon' '2020-04-18' 78 3]
#  ['Canada' '2020-04-18' 2211 180]
#  ['Cabo Verde' '2020-04-18' 15 0]
#  ['Central African Republic' '2020-04-18' 0 0]
#  ['Chad' '2020-04-18' 2 0]
#  ['Chile' '2020-04-18' 480 8]
#  ['China' '2020-04-18' 213 688]
#  ['Colombia' '2020-04-18' 225 10]
#  ['Congo' '2020-04-18' 32 0]
#  ['Congo (Democratic Republic of the)' '2020-04-18' 15 1]
#  ['Costa Rica' '2020-04-18' 11 0]
#  ['Croatia' '2020-04-18' 39 1]
#  ['Cuba' '2020-04-18' 52 3]
#  ['Cyprus' '2020-04-18' 18 0]
#  ['Czech Republic' '2020-04-18' 168 4]
#  ['Denmark' '2020-04-18' 192 15]
#  ['Djibouti' '2020-04-18' 139 0]
#  ['Dominica' '2020-04-18' 0 0]
#  ['Dominican Republic' '2020-04-18' 326 5]
#  ['Ecuador' '2020-04-18' 304 17]
#  ['Egypt' '2020-04-18' 171 10]
#  ['El Salvador' '2020-04-18' 10 0]
#  ['Equatorial Guinea' '2020-04-18' 18 0]
#  ['Eritrea' '2020-04-18' 0 0]
#  ['Estonia' '2020-04-18' 30 2]
#  ['Ethiopia' '2020-04-18' 5 0]
#  ['Fiji' '2020-04-18' 0 0]
#  ['Finland' '2020-04-18' 120 6]
#  ['France' '2020-04-18' 7780 986]
#  ['Gabon' '2020-04-18' 22 0]
#  ['Gambia' '2020-04-18' 0 0]
#  ['Georgia' '2020-04-18' 30 0]
#  ['Germany' '2020-04-18' 3496 363]
#  ['Ghana' '2020-04-18' 2 0]
#  ['Greece' '2020-04-18' 18 2]
#  ['Grenada' '2020-04-18' 0 0]
#  ['Guatemala' '2020-04-18' 18 0]
#  ['Guinea' '2020-04-18' 39 1]
#  ['Guinea-Bissau' '2020-04-18' 1 0]
#  ['Guyana' '2020-04-18' 6 0]
#  ['Haiti' '2020-04-18' 1 0]
#  ['Holy See' '2020-04-18' 0 0]
#  ['Honduras' '2020-04-18' 13 5]
#  ['Hungary' '2020-04-18' 120 12]
#  ['Iceland' '2020-04-18' 15 0]
#  ['India' '2020-04-18' 1009 37]
#  ['Indonesia' '2020-04-18' 413 23]
#  ["Côte d'Ivoire" '2020-04-18' 38 0]
#  ['Iran (Islamic Republic of)' '2020-04-18' 1557 91]
#  ['Iraq' '2020-04-18' 55 1]
#  ['Ireland' '2020-04-18' 858 44]
#  ['Israel' '2020-04-18' 320 10]
#  ['Italy' '2020-04-18' 3539 569]
#  ['Jamaica' '2020-04-18' 21 0]
#  ['Japan' '2020-04-18' 1319 21]
#  ['Jordan' '2020-04-18' 4 0]
#  ['Kazakhstan' '2020-04-18' 153 0]
#  ['Kenya' '2020-04-18' 10 0]
#  ['Kuwait' '2020-04-18' 137 0]
#  ['Kyrgyzstan' '2020-04-18' 20 0]
#  ["Lao People's Democratic Republic" '2020-04-18' 0 0]
#  ['Latvia' '2020-04-18' 8 0]
#  ['Lebanon' '2020-04-18' 9 0]
#  ['Liberia' '2020-04-18' 5 0]
#  ['Libya' '2020-04-18' 5 0]
#  ['Liechtenstein' '2020-04-18' 0 0]
#  ['Lithuania' '2020-04-18' 29 1]
#  ['Luxembourg' '2020-04-18' 58 2]
#  ['Macedonia (the former Yugoslav Republic of)' '2020-04-18' 77 1]
#  ['Madagascar' '2020-04-18' 4 0]
#  ['Malawi' '2020-04-18' 0 0]
#  ['Malaysia' '2020-04-18' 93 1]
#  ['Maldives' '2020-04-18' 2 0]
#  ['Mali' '2020-04-18' 12 0]
#  ['Malta' '2020-04-18' 11 0]
#  ['Mauritania' '2020-04-18' 0 0]
#  ['Mauritius' '2020-04-18' 0 0]
#  ['Mexico' '2020-04-18' 450 52]
#  ['Moldova (Republic of)' '2020-04-18' 111 5]
#  ['Monaco' '2020-04-18' 0 0]
#  ['Mongolia' '2020-04-18' 0 0]
#  ['Montenegro' '2020-04-18' 8 0]
#  ['Morocco' '2020-04-18' 286 5]
#  ['Mozambique' '2020-04-18' 3 0]
#  ['Namibia' '2020-04-18' 0 0]
#  ['Nepal' '2020-04-18' 4 0]
#  ['Netherlands' '2020-04-18' 1278 163]
#  ['New Zealand' '2020-04-18' 13 0]
#  ['Nicaragua' '2020-04-18' 0 0]
#  ['Niger' '2020-04-18' 27 1]
#  ['Nigeria' '2020-04-18' 55 2]
#  ['Norway' '2020-04-18' 112 8]
#  ['Oman' '2020-04-18' 87 0]
#  ['Pakistan' '2020-04-18' 289 13]
#  ['Panama' '2020-04-18' 287 6]
#  ['Papua New Guinea' '2020-04-18' 2 0]
#  ['Paraguay' '2020-04-18' 28 0]
#  ['Peru' '2020-04-18' 1070 24]
#  ['Philippines' '2020-04-18' 220 19]
#  ['Poland' '2020-04-18' 417 24]
#  ['Portugal' '2020-04-18' 546 29]
#  ['Qatar' '2020-04-18' 602 0]
#  ['Romania' '2020-04-18' 426 19]
#  ['Russian Federation' '2020-04-18' 4225 42]
#  ['Rwanda' '2020-04-18' 3 0]
#  ['Saint Kitts and Nevis' '2020-04-18' 0 0]
#  ['Saint Lucia' '2020-04-18' 0 0]
#  ['Saint Vincent and the Grenadines' '2020-04-18' 0 0]
#  ['San Marino' '2020-04-18' 31 1]
#  ['Sao Tome and Principe' '2020-04-18' 0 0]
#  ['Saudi Arabia' '2020-04-18' 823 4]
#  ['Senegal' '2020-04-18' 15 0]
#  ['Serbia' '2020-04-18' 415 5]
#  ['Seychelles' '2020-04-18' 0 0]
#  ['Sierra Leone' '2020-04-18' 5 0]
#  ['Singapore' '2020-04-18' 655 0]
#  ['Slovakia' '2020-04-18' 88 2]
#  ['Slovenia' '2020-04-18' 31 4]
#  ['Somalia' '2020-04-18' 25 1]
#  ['South Africa' '2020-04-18' 197 9]
#  ['Korea (Republic of)' '2020-04-18' 23 2]
#  ['South Sudan' '2020-04-18' 0 0]
#  ['Spain' '2020-04-18' 6539 664]
#  ['Sri Lanka' '2020-04-18' 4 0]
#  ['Sudan' '2020-04-18' 0 0]
#  ['Suriname' '2020-04-18' 0 0]
#  ['Swaziland' '2020-04-18' 0 0]
#  ['Sweden' '2020-04-18' 691 109]
#  ['Switzerland' '2020-04-18' 368 51]
#  ['Syrian Arab Republic' '2020-04-18' 4 0]
#  ['Taiwan' '2020-04-18' 0 0]
#  ['Tanzania, United Republic of' '2020-04-18' 40 0]
#  ['Thailand' '2020-04-18' 28 2]
#  ['Timor-Leste' '2020-04-18' 5 0]
#  ['Togo' '2020-04-18' 2 1]
#  ['Trinidad and Tobago' '2020-04-18' 0 0]
#  ['Tunisia' '2020-04-18' 39 1]
#  ['Turkey' '2020-04-18' 4582 126]
#  ['Uganda' '2020-04-18' 0 0]
#  ['Ukraine' '2020-04-18' 527 9]
#  ['United Arab Emirates' '2020-04-18' 481 3]
#  ['United Kingdom of Great Britain and Northern Ireland' '2020-04-18'
#   5864 846]
#  ['United States of America' '2020-04-18' 32018 4066]
#  ['Uruguay' '2020-04-18' 6 0]
#  ['Uzbekistan' '2020-04-18' 81 0]
#  ['Venezuela (Bolivarian Republic of)' '2020-04-18' 3 0]
#  ['Viet Nam' '2020-04-18' 0 0]
#  ['Western Sahara' '2020-04-18' 0 0]
#  ['Yemen' '2020-04-18' 0 0]
#  ['Zambia' '2020-04-18' 3 0]
#  ['Zimbabwe' '2020-04-18' 2 0]]

# %%
""""import csv

with open("PredOutput.csv", "w") as f2:
    fieldnames = ['country_name','date','affected_prediction','death_prediction']
    csv_writer = csv.DictWriter(f2, fieldnames= fieldnames)
    csv_writer.writeheader()
    csv_writer = csv.writer(f2)
    csv_writer.writerows(tempbase)""""

# %%
import csv

def append_list_as_row(file_name, list_of_elem):
    # Open file in append mode
    with open(file_name, 'a+', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = writer(write_obj)
        # Add contents of list as last row in the csv file
        csv_writer.writerow(list_of_elem)

# %%
append_list_as_row('PredOutput.csv',tempbase)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6
import numpy as np
import pandas as pd
fig = plt.figure()

# %% [markdown]
# BANGLADESH

# %%
df = pd.read_csv('bd1.csv')
df
# Out:
#     Unnamed: 0  BGD  4/18/2020   306   9   299  16   379   8  Bangladesh
# 0          NaN  BGD  4/19/2020   312   7   311  12   308  16  Bangladesh
# 1          NaN  BGD  4/20/2020   492  10   303   8   290  12  Bangladesh
# 2          NaN  BGD  4/21/2020   434   9   405   9   308   8  Bangladesh
# 3          NaN  BGD  4/22/2020   390  10   422   8   417   8  Bangladesh
# 4          NaN  BGD  4/20/2020   434   9   416   9   437   9  Bangladesh
# ..         ...  ...        ...   ...  ..   ...  ..   ...  ..         ...
# 67    121269.0  BGD  6/23/2020  3412  43  3799  44  3667  43  Bangladesh
# 68    121269.0  BGD  6/24/2020  3462  37  3980  46  3803  44  Bangladesh
# 69    121269.0  BGD  6/25/2020  3946  39  4013  45  3981  47  Bangladesh
# 70    121269.0  BGD  6/26/2020  3868  40  3991  44  4120  47  Bangladesh
# 71    121269.0  BGD  6/27/2020  3504  34  3998  45  4095  47  Bangladesh
#
# [72 rows x 10 columns]

# %%
df.to_csv("BD1.csv", header=["ID","Code","Date","ActualAffected","ActualDeath","One day prediction of affected","One day prediction of death","Two day prediction of affected","Two day prediction of death","Country name"], index=False)

# %%
df2 = pd.read_csv('BD1.csv')
df2
# Out:
#           ID Code       Date  ActualAffected  ActualDeath  \
# 0        NaN  BGD  4/18/2020             306            9
# 1        NaN  BGD  4/19/2020             312            7
# 2        NaN  BGD  4/20/2020             492           10
# 3        NaN  BGD  4/21/2020             434            9
# 4        NaN  BGD  4/22/2020             390           10
# ..       ...  ...        ...             ...          ...
# 68  121269.0  BGD  6/23/2020            3412           43
# 69  121269.0  BGD  6/24/2020            3462           37
# 70  121269.0  BGD  6/25/2020            3946           39
# 71  121269.0  BGD  6/26/2020            3868           40
# 72  121269.0  BGD  6/27/2020            3504           34
#
#     One_day_prediction_of_affected  One_day_prediction_of_death  \
# 0                              299                           16
# 1                              311                           12
# 2                              303                            8
# ...

# %%
df2 = df2.set_index(pd.to_datetime(df2.Date), drop=True)
df2.ActualAffected.plot(grid=True, label="Actual", legend=True)
df2.One_day_prediction_of_affected.plot(grid=True, label="One day", legend=True)
df2.Two_day_prediction_of_affected.plot(grid=True, label="Two day", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Affected Cases of Bangladesh for One and Two Days Prediction')
fig.savefig('BDaffected1and2.png',dpi=300, bbox_inches='tight')
plt.show()

# %%
df2.ActualDeath.plot(grid=True, label="Actual", legend=True)
df2.One_day_prediction_of_death.plot(grid=True, label="One day", legend=True)
df2.Two_day_prediction_of_death.plot(grid=True, label="Two day", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Death Cases of Bangladesh for One and Two Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Death Cases of Bangladesh for One and Two Days Prediction')

# %%
""""x = df2.iloc[:,2:3]
y1=df2.iloc[:,3:4]
y2=df2.iloc[:,5:6]
y3=df2.iloc[:,7:8]
X = [X[0] for X in x.values.tolist()]  #list comprehension
Y1 = [Y1[0] for Y1 in y1.values.tolist()]
Y2 = [Y2[0] for Y2 in y2.values.tolist()]
Y3 = [Y3[0] for Y3 in y3.values.tolist()]
fig, ax = plt.subplots()
ax.plot(X, Y1, '-b', label='Sine')
ax.plot(X, Y2, '--r', label='Cosine')
ax.plot(X, Y3, '--r', label='C')
ax.axis('equal')
leg = ax.legend();
""""""

# %% [markdown]
# AUSTRALIA

# %%
af = pd.read_csv('aus1.csv')
af.to_csv("aus1.csv", header=["ID","Code","Date","ActualAffected","ActualDeath","One_day_prediction_of_affected","One_day_prediction_of_death","Two_day_prediction_of_affected","Two_day_prediction_of_death","Countryname"], index=False)
# Out:
#           ID Code       Date  ActualAffected  ActualDeath  \
# 0        NaN  AUS  4/19/2020             0.0          0.0
# 1        NaN  AUS  4/20/2020            78.0          4.0
# 2        NaN  AUS  4/21/2020             0.0          0.0
# 3        NaN  AUS  4/22/2020           107.0          7.0
# 4        NaN  AUS  4/20/2020             0.0          0.0
# ..       ...  ...        ...             ...          ...
# 69  202014.0  AUS  6/25/2020            37.0          0.0
# 70  202014.0  AUS  6/26/2020             6.0          0.0
# 71  202014.0  AUS  6/27/2020            85.0          0.0
# 72  202014.0  AUS        NaN             NaN          NaN
# 73  202014.0  AUS        NaN             NaN          NaN
#
#     One_day_prediction_of affected  One_day_prediction_of_death  \
# 0                             41.0                          1.0
# 1                             15.0                          0.0
# 2                             47.0                          2.0
# ...

# %%
af2 = pd.read_csv('aus1.csv')
af2
# Out:
#           ID Code       Date  ActualAffected  ActualDeath  \
# 0        NaN  AUS  4/18/2020              25            1
# 1        NaN  AUS  4/19/2020               0            0
# 2        NaN  AUS  4/20/2020              78            4
# 3        NaN  AUS  4/21/2020               0            0
# 4        NaN  AUS  4/22/2020             107            7
# ..       ...  ...        ...             ...          ...
# 68  202014.0  AUS  6/23/2020              29            1
# 69  202014.0  AUS  6/24/2020              37            1
# 70  202014.0  AUS  6/25/2020              37            0
# 71  202014.0  AUS  6/26/2020               6            0
# 72  202014.0  AUS  6/27/2020              85            0
#
#     One_day_prediction_of_affected  One_day_prediction_of_death  \
# 0                               43                            1
# 1                               41                            1
# 2                               15                            0
# ...

# %%
af2 = af2.set_index(pd.to_datetime(af2.Date), drop=True)
af2.ActualAffected.plot(grid=True, label="Actual", legend=True)
af2.One_day_prediction_of_affected.plot(grid=True, label="One day", legend=True)
af2.Two_day_prediction_of_affected.plot(grid=True, label="Two day", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Affected Cases of Australia for One and Two Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Affected Cases of Australia for One and Two Days Prediction')

# %%
af2.ActualDeath.plot(grid=True, label="Actual", legend=True)
af2.One_day_prediction_of_death.plot(grid=True, label="One day", legend=True)
af2.Two_day_prediction_of_death.plot(grid=True, label="Two day", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Death Cases of Australia for One and Two Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Death Cases of Australia for One and Two Days Prediction')

# %% [markdown]
# CANADA

# %%
cf = pd.read_csv('cnd1.csv')
cf.to_csv("cnd1.csv", header=["ID","Code","Date","ActualAffected","ActualDeath","One_day_prediction_of_affected","One_day_prediction_of_death","Two_day_prediction_of_affected","Two_day_prediction_of_death","Countryname"], index=False)

# %%
cf2 = pd.read_csv('cnd1.csv')
cf2
# Out:
#           ID Code       Date  ActualAffected  ActualDeath  \
# 0        NaN  CAN  4/18/2020            1542           45
# 1        NaN  CAN  4/19/2020            1277          164
# 2        NaN  CAN  4/20/2020            1196          126
# 3        NaN  CAN  4/21/2020            1744          183
# 4        NaN  CAN  4/22/2020             788           65
# ..       ...  ...        ...             ...          ...
# 68  202043.0  CAN  6/23/2020             349           18
# 69  202043.0  CAN  6/24/2020             320           32
# 70  202043.0  CAN  6/25/2020             376           23
# 71  202043.0  CAN  6/26/2020             166            4
# 72  202043.0  CAN  6/27/2020             249            5
#
#     One_day_prediction_of_affected  One_day_prediction_of_death  \
# 0                             2211                          180
# 1                             1815                           93
# 2                             1457                          121
# ...

# %%
cf2 = cf2.set_index(pd.to_datetime(cf2.Date), drop=True)
cf2.ActualAffected.plot(grid=True, label="Actual", legend=True)
cf2.One_day_prediction_of_affected.plot(grid=True, label="One day", legend=True)
cf2.Two_day_prediction_of_affected.plot(grid=True, label="Two day", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Affected Cases of Canada for One and Two Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Affected Cases of Canada for One and Two Days Prediction')

# %%
cf2.ActualDeath.plot(grid=True, label="Actual", legend=True)
cf2.One_day_prediction_of_death.plot(grid=True, label="One day", legend=True)
cf2.Two_day_prediction_of_death.plot(grid=True, label="Two day", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Death Cases of Canada for One and Two Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Death Cases of Canada for One and Two Days Prediction')

# %% [markdown]
# # DOING FOR 30 DAYS

# %% [markdown]
# BANGLADESH

# %%
bd2 = pd.read_csv('30dyasbd.csv')
bd2['Date'] =pd.to_datetime(bd2.Date)
df2['Date'] =pd.to_datetime(df2.Date)
bd2
# Out:
#          Date  medianvalue  maximum  minimum Countryname
# 0  2020-06-06         2357     2679     1211  Bangladesh
# 1  2020-06-07         3538     4147     1591  Bangladesh
# 2  2020-06-08         2874     3292     1426  Bangladesh
# 3  2020-06-09         2795     3198     1397  Bangladesh
# 4  2020-06-10         2698     3094     1330  Bangladesh
# 5  2020-06-11         3481     4105     1521  Bangladesh
# 6  2020-06-12         4207     5130     1603  Bangladesh
# 7  2020-06-13         5571     7149     1742  Bangladesh
# 8  2020-06-14         5391     6923     1685  Bangladesh
# 9  2020-06-15         4769     5952     1649  Bangladesh
# 10 2020-06-16         5066     6417     1655  Bangladesh
# 11 2020-06-17         5577     7249     1653  Bangladesh
# 12 2020-06-18         4963     6351     2736  Bangladesh
# 13 2020-06-19         5907     7853     3011  Bangladesh
# 14 2020-06-20         6987     9883     3159  Bangladesh
# ...

# %%
#df2= df2.set_index('ID')
df3 = df2.merge(bd2,on='Date',how='right')
df3
# Out:
#    Code       Date  ActualAffected  ActualDeath  \
# 0   BGD 2020-06-06            2635           35
# 1   BGD 2020-06-07            2743           42
# 2   BGD 2020-06-08            2735           42
# 3   BGD 2020-06-09            3171           45
# 4   BGD 2020-06-10            3190           37
# 5   BGD 2020-06-10            3190           37
# 6   BGD 2020-06-11            3187           37
# 7   BGD 2020-06-12            3471           46
# 8   BGD 2020-06-13            2856           44
# 9   BGD 2020-06-13            2856           44
# 10  BGD 2020-06-14            3141           32
# 11  BGD 2020-06-15            3099           38
# 12  BGD 2020-06-16            3862           53
# 13  BGD 2020-06-17            4008           43
# 14  BGD 2020-06-18            3803           38
# 15  BGD 2020-06-19            3243           45
# 16  BGD 2020-06-20            3240           37
# 17  BGD 2020-06-21            3531           39
# ...

# %%
df3 = df3.set_index(pd.to_datetime(df3.Date), drop=True)
df3.ActualAffected.plot(grid=True, label="Actual", legend=True)
df3.maximum.plot(grid=True, label="Maximum", legend=True)
df3.medianvalue.plot(grid=True, label="Median", legend=True)
df3.minimum.plot(grid=True, label="Minimum", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Affected cases of Bangladesh for 30 days prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Affected cases of Bangladesh for 30 days prediction')

# %%
bd3 = pd.read_csv('30daysbd2.csv')
bd3['Date'] =pd.to_datetime(bd3.Date)
df2['Date'] =pd.to_datetime(df2.Date)
df4 = df2.merge(bd3,on='Date',how='right')
df4
# Out:
#    Code       Date  ActualAffected  ActualDeath  \
# 0   BGD 2020-06-06            2635           35
# 1   BGD 2020-06-07            2743           42
# 2   BGD 2020-06-08            2735           42
# 3   BGD 2020-06-09            3171           45
# 4   BGD 2020-06-10            3190           37
# 5   BGD 2020-06-10            3190           37
# 6   BGD 2020-06-11            3187           37
# 7   BGD 2020-06-12            3471           46
# 8   BGD 2020-06-13            2856           44
# 9   BGD 2020-06-13            2856           44
# 10  BGD 2020-06-14            3141           32
# 11  BGD 2020-06-15            3099           38
# 12  BGD 2020-06-16            3862           53
# 13  BGD 2020-06-17            4008           43
# 14  BGD 2020-06-18            3803           38
# 15  BGD 2020-06-19            3243           45
# 16  BGD 2020-06-20            3240           37
# 17  BGD 2020-06-21            3531           39
# ...

# %%
df4 = df4.set_index(pd.to_datetime(df4.Date), drop=True)
df4.ActualDeath.plot(grid=True, label="Actual", legend=True)
df4.maximum.plot(grid=True, label="Maximum", legend=True)
df4.medianvalue.plot(grid=True, label="Median", legend=True)
df4.minimum.plot(grid=True, label="Minimum", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Death cases of Bangladesh for 30 days prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Death cases of Bangladesh for 30 days prediction')

# %% [markdown]
# AUSTRALIA

# %%
aus2 = pd.read_csv('30daysaus1.csv')
aus2['Date'] =pd.to_datetime(aus2.Date)
#af2= af2.set_index('ID')
af2['Date'] =pd.to_datetime(af2.Date)
af3 = af2.merge(aus2,on='Date',how='right')
af3
# Out:
#    Code       Date  ActualAffected  ActualDeath  \
# 0   AUS 2020-06-06               7            0
# 1   AUS 2020-06-07               6            0
# 2   AUS 2020-06-08               2            0
# 3   AUS 2020-06-09               7            0
# 4   AUS 2020-06-10              11            0
# 5   AUS 2020-06-10              11            0
# 6   AUS 2020-06-11               4            0
# 7   AUS 2020-06-12               5            0
# 8   AUS 2020-06-13              26            0
# 9   AUS 2020-06-13              26            0
# 10  AUS 2020-06-14              15            0
# 11  AUS 2020-06-15              12            0
# 12  AUS 2020-06-16              23            0
# 13  AUS 2020-06-17              21            0
# 14  AUS 2020-06-18              18            0
# 15  AUS 2020-06-19               2            0
# 16  AUS 2020-06-20              50            0
# 17  AUS 2020-06-21              13            0
# ...

# %%
af3 = af3.set_index(pd.to_datetime(af3.Date), drop=True)
af3.ActualAffected.plot(grid=True, label="Actual", legend=True)
af3.maximum.plot(grid=True, label="Maximum", legend=True)
af3.medianvalue.plot(grid=True, label="Median", legend=True)
af3.minimum.plot(grid=True, label="Minimum", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Affected Cases of Australia for 30 Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Affected Cases of Australia for 30 Days Prediction')

# %%
aus3 = pd.read_csv('30daysaus2.csv')
aus3['Date'] =pd.to_datetime(aus3.Date)
#af2= af2.set_index('ID')
af2['Date'] =pd.to_datetime(af2.Date)
af4 = af2.merge(aus3,on='Date',how='right')
af4
# Out:
#    Code       Date  ActualAffected  ActualDeath  \
# 0   AUS 2020-06-06               7            0
# 1   AUS 2020-06-07               6            0
# 2   AUS 2020-06-08               2            0
# 3   AUS 2020-06-09               7            0
# 4   AUS 2020-06-10              11            0
# 5   AUS 2020-06-10              11            0
# 6   AUS 2020-06-11               4            0
# 7   AUS 2020-06-12               5            0
# 8   AUS 2020-06-13              26            0
# 9   AUS 2020-06-13              26            0
# 10  AUS 2020-06-14              15            0
# 11  AUS 2020-06-15              12            0
# 12  AUS 2020-06-16              23            0
# 13  AUS 2020-06-17              21            0
# 14  AUS 2020-06-18              18            0
# 15  AUS 2020-06-19               2            0
# 16  AUS 2020-06-20              50            0
# 17  AUS 2020-06-21              13            0
# ...

# %%
af4 = af4.set_index(pd.to_datetime(af4.Date), drop=True)
af4.ActualDeath.plot(grid=True, label="Actual", legend=True)
af4.maximum.plot(grid=True, label="Maximum", legend=True)
af4.medianvalue.plot(grid=True, label="Median", legend=True)
af4.minimum.plot(grid=True, label="Minimum", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Death Cases of Australia for 30 Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Death Cases of Australia for 30 Days Prediction')

# %%
cnd2 = pd.read_csv('30dayscana1.csv')
cnd2['Date'] =pd.to_datetime(cnd2.Date)
cf2= cf2.set_index('ID')
cf2['Date'] =pd.to_datetime(cf2.Date)
cf3 = cf2.merge(cnd2,on='Date',how='right')
cf3
# Out:
#    Code       Date  ActualAffected  ActualDeath  \
# 0   CAN 2020-06-06             528           72
# 1   CAN 2020-06-07             703           27
# 2   CAN 2020-06-08             601           33
# 3   CAN 2020-06-09             462           60
# 4   CAN 2020-06-10             479           68
# 5   CAN 2020-06-10             479           68
# 6   CAN 2020-06-11             439           33
# 7   CAN 2020-06-12             436           54
# 8   CAN 2020-06-13             448           58
# 9   CAN 2020-06-13             448           58
# 10  CAN 2020-06-14             361           35
# 11  CAN 2020-06-15             359           10
# 12  CAN 2020-06-16             324           43
# 13  CAN 2020-06-17             404           41
# 14  CAN 2020-06-18             386           49
# 15  CAN 2020-06-19             437           47
# 16  CAN 2020-06-20             448           58
# 17  CAN 2020-06-21             316           16
# ...

# %%
cf3 = cf3.set_index(pd.to_datetime(cf3.Date), drop=True)
cf3.ActualAffected.plot(grid=True, label="Actual", legend=True)
cf3.maximum.plot(grid=True, label="Maximum", legend=True)
cf3.medianvalue.plot(grid=True, label="Median", legend=True)
cf3.minimum.plot(grid=True, label="Minimum", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Affected Cases of Canada for 30 Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Affected Cases of Canada for 30 Days Prediction')

# %%
cnd3 = pd.read_csv('30dayscana2.csv')
cnd3['Date'] =pd.to_datetime(cnd3.Date)
#cf2= cf2.set_index('ID')
cf2['Date'] =pd.to_datetime(cf2.Date)
cf4 = cf2.merge(cnd3,on='Date',how='right')
cf4
# Out:
#    Code       Date  ActualAffected  ActualDeath  \
# 0   CAN 2020-06-06             528           72
# 1   CAN 2020-06-07             703           27
# 2   CAN 2020-06-08             601           33
# 3   CAN 2020-06-09             462           60
# 4   CAN 2020-06-10             479           68
# 5   CAN 2020-06-10             479           68
# 6   CAN 2020-06-11             439           33
# 7   CAN 2020-06-12             436           54
# 8   CAN 2020-06-13             448           58
# 9   CAN 2020-06-13             448           58
# 10  CAN 2020-06-14             361           35
# 11  CAN 2020-06-15             359           10
# 12  CAN 2020-06-16             324           43
# 13  CAN 2020-06-17             404           41
# 14  CAN 2020-06-18             386           49
# 15  CAN 2020-06-19             437           47
# 16  CAN 2020-06-20             448           58
# 17  CAN 2020-06-21             316           16
# ...

# %%
cf4= cf4.set_index(pd.to_datetime(cf4.Date), drop=True)
cf4.ActualDeath.plot(grid=True, label="Actual", legend=True)
cf4.maximum.plot(grid=True, label="Maximum", legend=True)
cf4.medianvalue.plot(grid=True, label="Median", legend=True)
cf4.minimum.plot(grid=True, label="Minimum", legend=True)
plt.legend(loc='best')
plt.title('Actual and Predicted Death Cases of Canada for 30 Days Prediction')
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Death Cases of Canada for 30 Days Prediction')
